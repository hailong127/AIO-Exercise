# %% [markdown]
# # **BÀI TẬP**

# %% [markdown]
# ## **Credit Card Fraud Detection**

# %% [markdown]
# **1. Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **2. Đọc dữ liệu**

# %%
dataset_path = 'creditcard.csv'
df = pd.read_csv(dataset_path)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# **3. Tách biến X, y**: Chuyển đổi DataFrame hiện tại thành array và tách hai biến X, y

# %%
dataset_arr = df.to_numpy()
X, y = dataset_arr[:, :-1].astype(np.float64), dataset_arr[:, -1].astype(np.uint8)

# %% [markdown]
# **4. Thêm bias vào X:** Khi sử dụng thư viện, bias sẽ được thêm tự động. Tuy nhiên, khi triển khai lại từ đầu cần phải tự thêm bias vào mỗi mẫu dữ liệu, nhằm thỏa mãn công thức hàm dự đoán

# %%
intercept = np.ones((X.shape[0], 1))
X_b = np.concatenate((intercept, X), axis = 1)

# %% [markdown]
# **5. One-hot encoding:** Đối với Softmax Regression, sau khi có biến chứa nhãn dữ liệu y, ta cần phải thay đổi cách biểu diễn giá trị của nhãn trước khi thực hiện tính toán

# %%
n_classes = np.unique(y, axis=0).shape[0]
n_samples = y.shape[0]

y_encoded = np.array([np.zeros(n_classes) for _ in range(n_samples)])
y_encoded[np.arange(n_samples), y] = 1

# %% [markdown]
# **6. Chia tập train, val, test**

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True
X_train, X_val, y_train, y_val = train_test_split(X_b, y_encoded, test_size = val_size, random_state = random_state, shuffle = is_shuffle)
X_train, X_test, y_train, y_test = train_test_split(X_b, y_encoded, test_size = test_size, random_state = random_state, shuffle = is_shuffle)

# %% [markdown]
# **7. Chuẩn hóa dữ liệu:** Sử dụng X_train vừa tạo ở trên fit vào hàm chuẩn hóa StandardScaler, sau đó đem scaler này chuẩn hóa cho tập X_val và X_test(không chuẩn hóa bias nên sẽ bỏ qua cột đầu tiên trong X)

# %%
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %% [markdown]
# **8. Cài đặt các hàm quan trọng**

# %% [markdown]
# Hàm softmax

# %%
def softmax(z):
    exp_z = np.exp(z)

    return exp_z / exp_z.sum(axis=1)[:, None]

# %% [markdown]
# Hàm dự đoán

# %%
def predict(X, theta):
    z = np.dot(X, theta)
    y_hat = softmax(z)

    return y_hat

# %% [markdown]
# Hàm tính loss

# %%
def compute_loss(y_hat, y):
    n = y.size
    return (-1 / n) * np.sum(y * np.log(y_hat))

# %% [markdown]
# Hàm tính gradient

# %%
def compute_gradient(X, y, y_hat):
    n = y.size
    return np.dot(X.T, (y_hat - y)) / n

# %% [markdown]
# Hàm cập nhật trọng số

# %%
def update_theta(theta, gradient, lr):
    return theta - lr * gradient

# %% [markdown]
# Hàm tính độ chính xác

# %%
def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta)
    acc = (np.argmax(y_hat, axis=1) == np.argmax(y, axis=1)).mean()

    return acc

# %% [markdown]
# **9. Khai báo các siêu tham số và khởi tạo weights:**

# %%
lr = 0.01
epochs = 30
batch_size = 1024
n_features = X_train.shape[1]

np.random.seed(random_state)
theta = np.random.uniform(size = (n_features, n_classes))

# %% [markdown]
# **10. Huấn luyện mô hình:**

# %%
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
    train_batch_losses = []
    train_batch_accs = []
    val_batch_losses = []
    val_batch_accs = []

    for i in range(0, X_train.shape[0], batch_size):
        X_i = X_train[i: i + batch_size]
        y_i = y_train[i: i + batch_size]

        y_hat = predict(X_i, theta)
        train_loss = compute_loss(y_hat, y_i)
        gradient = compute_gradient(X_i, y_i, y_hat)
        theta = update_theta(theta, gradient, lr)

        train_batch_losses.append(train_loss)

        train_acc = compute_accuracy(X_train, y_train, theta)
        train_batch_accs.append(train_acc)

        y_val_hat = predict(X_val, theta)
        val_loss = compute_loss(y_val_hat, y_val)
        val_batch_losses.append(val_loss)

        val_acc = compute_accuracy(X_val, y_val, theta)
        val_batch_accs.append(val_acc)
    train_batch_loss = sum(train_batch_losses) / len(train_batch_losses)
    val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
    train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
    val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

    train_accs.append(train_batch_acc)
    train_losses.append(train_batch_loss)
    val_accs.append(val_batch_acc)
    val_losses.append(val_batch_loss)

    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 0.282	Validation loss: 0.279
#
# EPOCH 2:	Training loss: 0.149	Validation loss: 0.147
#
# EPOCH 3:	Training loss: 0.092	Validation loss: 0.091
#
# EPOCH 4:	Training loss: 0.064	Validation loss: 0.063
#
# EPOCH 5:	Training loss: 0.048	Validation loss: 0.048
#
# EPOCH 6:	Training loss: 0.039	Validation loss: 0.038
#
# EPOCH 7:	Training loss: 0.032	Validation loss: 0.032
#
# EPOCH 8:	Training loss: 0.028	Validation loss: 0.028
#
# EPOCH 9:	Training loss: 0.025	Validation loss: 0.024
#
# EPOCH 10:	Training loss: 0.022	Validation loss: 0.022
#
# EPOCH 11:	Training loss: 0.020	Validation loss: 0.020
#
# EPOCH 12:	Training loss: 0.019	Validation loss: 0.018
#
# EPOCH 13:	Training loss: 0.017	Validation loss: 0.017
#
# EPOCH 14:	Training loss: 0.016	Validation loss: 0.016
#
# EPOCH 15:	Training loss: 0.015	Validation loss: 0.015
#
# EPOCH 16:	Training loss: 0.014	Validation loss: 0.014
#
# EPOCH 17:	Training loss: 0.014	Validation loss: 0.013
#
# ...

# %%
fig, ax = plt.subplots(2, 2, figsize=(12 , 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, 'orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# **11. Đánh giá mô hình:**

# %%
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy(X_test, y_test, theta)
print('Evaluation on validation and test set:')
print(f'Accuracy: { val_set_acc }')
print(f'Accuracy : { test_set_acc }')
# Out:
# Evaluation on validation and test set:
# Accuracy: 0.9992802219023208
# Accuracy : 0.9992977725344794

# %% [markdown]
# ## **Twitter Sentiment Analysis**

# %% [markdown]
# **1. Import libraries**

# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt
nltk.download('stopwords')

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **2. Đọc bộ dữ liệu**

# %%
dataset_path = 'Twitter_Data.csv'
df = pd.read_csv(dataset_path)
df
# Out:
#                                                clean_text  category
# 0       when modi promised “minimum government maximum...      -1.0
# 1       talk all the nonsense and continue all the dra...       0.0
# 2       what did just say vote for modi  welcome bjp t...       1.0
# 3       asking his supporters prefix chowkidar their n...       1.0
# 4       answer who among these the most powerful world...       1.0
# ...                                                   ...       ...
# 162975  why these 456 crores paid neerav modi not reco...      -1.0
# 162976  dear rss terrorist payal gawar what about modi...      -1.0
# 162977  did you cover her interaction forum where she ...       0.0
# 162978  there big project came into india modi dream p...       0.0
# 162979  have you ever listen about like gurukul where ...       1.0
#
# [162980 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162980 entries, 0 to 162979
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   clean_text  162976 non-null  object
#  1   category    162973 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#             category
# count  162973.000000
# mean        0.225436
# std         0.781279
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %%
df.tail()
# Out:
#                                                clean_text  category
# 162975  why these 456 crores paid neerav modi not reco...      -1.0
# 162976  dear rss terrorist payal gawar what about modi...      -1.0
# 162977  did you cover her interaction forum where she ...       0.0
# 162978  there big project came into india modi dream p...       0.0
# 162979  have you ever listen about like gurukul where ...       1.0

# %% [markdown]
# **3. Xóa missing data**: bộ dữ liệu này có tồn tại một vài hàng chứa giá trị null

# %%
df = df.dropna()

# %% [markdown]
# **4. Tiền xử lý bộ dữ liệu**: dữ liệu đầu vào đang ở dạng văn bản (string). Vì vậy sẽ phải tiền xử lý dữ liệu văn bản đầu vào để đưa về một dạng vector đặc trưng nào đó

# %% [markdown]
# (a) Xây dựng hàm chuẩn hóa văn bản: văn bản gốc có rất nhiều kí tự dư thừa, vô nghĩa vì vậy cần phải loại bỏ chúng cũng như áp dụng thêm vài bước chuẩn hóa văn bản khác để văn bản đầu vào trở nên ít phức tạp hơn, nhằm tăng cường hiệu quả biểu diễn của vector đặc trưng sau này.

# %%
def text_normalize(text):
    # Lowercasing
    text = text.lower()
    # Retweet old acronym "RT" removal
    text = re.sub(r'^rt[\s]+', '', text)
    # Hyperlinks removal
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)
    # Punctuation removal
    text = re.sub(r'[^\w\s]+', '', text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))

    words = text.split()
    words = [word for word in words if word not in stop_words]
    text = ' '.join(words)

    # Stemming
    stemmer = SnowballStemmer('english')
    words = text.split()
    words = [stemmer.stem(word) for word in words]
    text = ' '.join(words)

    return text

# %% [markdown]
# (b) Khởi tạo tf-idf vectorizer: Trong bài này sẽ sử dụng một dạng vector
# biểu diễn đặc trưng mới cho văn bản đó là tf-idf

# %%
vectorizer = TfidfVectorizer(max_features = 2000)
X = vectorizer.fit_transform(df['clean_text']).toarray()

# %% [markdown]
# (c) Thêm bias vào X

# %%
intercept = np.ones((X.shape[0], 1))
X_b = np.concatenate((intercept, X), axis = 1)

# %% [markdown]
# **5. One-hot encoding label**

# %%
n_classes = df['category'].nunique()
n_samples = df['category'].size

y = df['category'].to_numpy() + 1
y = y.astype(np.uint8)
y_encoded = np.array([np.zeros(n_classes) for _ in range(n_samples)])
y_encoded[np.arange(n_samples), y] = 1

# %% [markdown]
# **6. Chia bộ train, val, test**

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True
X_train, X_val, y_train, y_val = train_test_split(X_b, y_encoded, test_size = val_size, random_state = random_state, shuffle = is_shuffle)
X_train, X_test, y_train, y_test = train_test_split(X_b, y_encoded, test_size = test_size, random_state = random_state, shuffle = is_shuffle)

# %% [markdown]
# **7. Cài đặt các hàm quan trọng**

# %%
def softmax(z):
    exp_z = np.exp(z)

    return exp_z / exp_z.sum(axis=1)[:, None]

def compute_loss(y_hat, y):
    n = y.size
    return (-1 / n) * np.sum(y * np.log(y_hat))

def predict(X, theta):
    z = np.dot(X, theta)
    y_hat = softmax(z)

    return y_hat

def compute_gradient(X, y, y_hat):
    n = y.size
    return np.dot(X.T, (y_hat - y)) / n

def update_theta(theta, gradient, lr):
    return theta - lr * gradient

def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta)
    acc = (np.argmax(y_hat, axis=1) == np.argmax(y, axis=1)).mean()

    return acc

# %% [markdown]
# **8. Khai báo các siêu tham số và khởi tạo weights:** vì số lượng mẫu dữ liệu rất lớn nên có thể cân nhắc tăng số batch_size lên để tăng tốc độ huấn luyện

# %%
lr = 0.01
epochs = 200
batch_size = X_train.shape[0]
n_features = X_train.shape[1]

np.random.seed(random_state)
theta = np.random.uniform(size = (n_features, n_classes))

# %% [markdown]
# **9. Huấn luyện mô hình**

# %%
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
    train_batch_losses = []
    train_batch_accs = []
    val_batch_losses = []
    val_batch_accs = []

    for i in range(0, X_train.shape[0], batch_size):
        X_i = X_train[i: i + batch_size]
        y_i = y_train[i: i + batch_size]

        y_hat = predict(X_i, theta)
        train_loss = compute_loss(y_hat, y_i)
        gradient = compute_gradient(X_i, y_i, y_hat)
        theta = update_theta(theta, gradient, lr)

        train_batch_losses.append(train_loss)

        train_acc = compute_accuracy(X_train, y_train, theta)
        train_batch_accs.append(train_acc)

        y_val_hat = predict(X_val, theta)
        val_loss = compute_loss(y_val_hat, y_val)
        val_batch_losses.append(val_loss)

        val_acc = compute_accuracy(X_val, y_val, theta)
        val_batch_accs.append(val_acc)
    train_batch_loss = sum(train_batch_losses) / len(train_batch_losses)
    val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
    train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
    val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

    train_accs.append(train_batch_acc)
    train_losses.append(train_batch_loss)
    val_accs.append(val_batch_acc)
    val_losses.append(val_batch_loss)

    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 0.368	Validation loss: 0.367
#
# EPOCH 2:	Training loss: 0.368	Validation loss: 0.367
#
# EPOCH 3:	Training loss: 0.368	Validation loss: 0.367
#
# EPOCH 4:	Training loss: 0.368	Validation loss: 0.367
#
# EPOCH 5:	Training loss: 0.368	Validation loss: 0.367
#
# EPOCH 6:	Training loss: 0.368	Validation loss: 0.367
#
# EPOCH 7:	Training loss: 0.367	Validation loss: 0.367
#
# EPOCH 8:	Training loss: 0.367	Validation loss: 0.367
#
# EPOCH 9:	Training loss: 0.367	Validation loss: 0.367
#
# EPOCH 10:	Training loss: 0.367	Validation loss: 0.367
#
# EPOCH 11:	Training loss: 0.367	Validation loss: 0.367
#
# EPOCH 12:	Training loss: 0.367	Validation loss: 0.367
#
# EPOCH 13:	Training loss: 0.367	Validation loss: 0.367
#
# EPOCH 14:	Training loss: 0.367	Validation loss: 0.367
#
# EPOCH 15:	Training loss: 0.367	Validation loss: 0.367
#
# EPOCH 16:	Training loss: 0.367	Validation loss: 0.367
#
# EPOCH 17:	Training loss: 0.367	Validation loss: 0.367
#
# ...

# %%
fig, ax = plt.subplots(2, 2, figsize=(12 , 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, 'orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# **10. Đánh giá mô hình**

# %%
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy(X_test, y_test, theta)
print('Evaluation on validation and test set:')
print(f'Accuracy: { val_set_acc }')
print(f'Accuracy : { test_set_acc }')
# Out:
# Evaluation on validation and test set:
# Accuracy: 0.4149536724550531
# Accuracy : 0.4154722167681131
